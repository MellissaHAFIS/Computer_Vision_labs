# %% [markdown]
# # Lab1 — Part 2: Training on MNIST
#
# **Course**: Deep Learning for Image Analysis
#
# **Class**: M2 IASD App
#
# **Professor**: Mehyar MLAWEH
#
# ---
#
# In this part, we move from a **toy dataset** to a **real image dataset**.
# We will train a neural network on **MNIST**, **without using CNNs**.
#
# The goal is to understand **why CNNs are needed**, not to use them yet.

# %% [markdown]
# ## Learning objectives
#
# After this part, you should understand:
# - How images are represented as **vectors**
# - How a neural network processes image data
# - How multi-class classification works
# - Why fully-connected networks are **not optimal** for vision tasks

# %% [markdown]
# ## 0) Environment setup
#
# Make sure you are using **GPU**:
# - Runtime → Change runtime type → GPU

# %%
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cpu

# %% [markdown]
# ## 1) Imports

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt

import torchvision
import torchvision.transforms as transforms

# %% [markdown]
# ## 2) The MNIST dataset
#
# MNIST contains **handwritten digit images**:
# - Image size: **28 × 28**
# - Number of channels: **1 (grayscale)**
# - Number of classes: **10** (digits 0–9)
#
# Each image is originally a **2D grid of pixels**, but a fully-connected network
# expects a **vector** as input.
#
# https://www.youtube.com/watch?v=SrT6QkQUH4Q

# %% [markdown]
# ### 🔍 Question (conceptual)
#
# - How many pixels does one MNIST image contain?
#
#   Each MNIST image is 28x28 pixels, so it contains 784 pixels.
# - What will be the size of the input vector after flattening?
#
#   After flattening, the input vector will have a size of 784 (28 * 28).

# %%
transform = transforms.ToTensor()

train_dataset = torchvision.datasets.MNIST(
    root="./data",
    train=True,
    download=True,
    transform=transform
)

test_dataset = torchvision.datasets.MNIST(
    root="./data",
    train=False,
    download=True,
    transform=transform
)

len(train_dataset), len(test_dataset)
# Out:
# (60000, 10000)

# %%
num_images = 6

plt.figure(figsize=(10, 3))

for i in range(num_images):
    image, label = train_dataset[i]

    plt.subplot(1, num_images, i + 1)
    plt.imshow(image.squeeze(), cmap="gray")
    plt.title(f"Label: {label}")
    plt.axis("off")

plt.suptitle("Sample images from the MNIST training dataset")
plt.show()

# %% [markdown]
# ## 3) DataLoader and mini-batches
#
# We use **mini-batches** to train efficiently.
#
# ⚠️ Choosing the batch size is a trade-off between speed and memory.

# %%
batch_size = 128

train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# ## 4) Model: Fully-connected neural network (MLP)
#
# ### Two experiments with the same model
#
# In this part, we train **the same neural network (MLP)** on two versions of MNIST:
#
# 1. **Original MNIST** (centered digits)
# 2. **Transformed MNIST** (shifted and rotated digits)

# %% [markdown]
# #### Experiment 1: MNIST (baseline)
#
# 1. **Flatten** the image `(1, 28, 28)` → `(784,)`
# 2. Feed it to a standard MLP
#
# Architecture:
# - Input: 784
# - Hidden layer: 256 neurons + ReLU
# - Output: 10 neurons (one per class)
#
# The output represents **class scores (logits)**.

# %%
class MLP_MNIST(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(
            nn.Flatten(),
            nn.Linear(28 * 28, 256),
            nn.ReLU(),
            nn.Linear(256, 10)
        )

    def forward(self, x):
        return self.net(x)

model = MLP_MNIST().to(device)
model
# Out:
# MLP_MNIST(
#   (net): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=784, out_features=256, bias=True)
#     (2): ReLU()
#     (3): Linear(in_features=256, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# ### ✅ TODO — Understanding the model
#
# 1. How many parameters does this model have?
#
# 784 * 256 + 256 + 256 * 10 + 10
# 1. Which layer contains most of the parameters?
# Explain briefly.
# The first layer (input to hidden) contains most of the parameters because it has 784 * 256 weights plus 256 biases, which is significantly larger than the second layer's parameters. Because the input dimension is high (784), the number of weights in the first layer becomes very large.

# %% [markdown]
#  **Loss function and optimizer**
#
# This is a **multi-class classification** problem.
#
# - We use `CrossEntropyLoss`
# - It combines **Softmax + Negative Log-Likelihood**

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=1e-3)

# %% [markdown]
# **Training loop**
#
# The training logic is **exactly the same** as before.
# Only the data and the model changed.

# %%
epochs = 10

for epoch in range(epochs):
    model.train()
    running_loss = 0.0

    for images, labels in train_loader:
        images = images.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)

        loss.backward()
        optimizer.step()

        running_loss += loss.item()

    avg_loss = running_loss / len(train_loader)
    print(f"Epoch {epoch+1}/{epochs} - Loss: {avg_loss:.4f}")
# Out:
# Epoch 1/10 - Loss: 0.3589
# Epoch 2/10 - Loss: 0.1562
# Epoch 3/10 - Loss: 0.1070
# Epoch 4/10 - Loss: 0.0804
# Epoch 5/10 - Loss: 0.0634
# Epoch 6/10 - Loss: 0.0505
# Epoch 7/10 - Loss: 0.0413
# Epoch 8/10 - Loss: 0.0326
# Epoch 9/10 - Loss: 0.0262
# Epoch 10/10 - Loss: 0.0213

# %% [markdown]
# **Evaluation on the test set**
#
# We compute the **classification accuracy**.

# %%
model.eval()
correct = 0
total = 0

with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)

        outputs = model(images)
        _, predicted = torch.max(outputs, 1)

        total += labels.size(0)
        correct += (predicted == labels).sum().item()

accuracy = correct / total
accuracy
# Out:
# 0.9787

# %% [markdown]
# #### Experiment 2: Shifted and rotated MNIST
#
# We now apply random shifts and rotations to the training images.
#
# This breaks the assumption that digits are always centered and aligned.
#
# The **model architecture remains exactly the same**.

# %%
transform_augmented = transforms.Compose([
    transforms.RandomAffine(
        degrees=50,
        translate=(0.2, 0.2)
    ),
    transforms.ToTensor()
])

train_dataset_aug = torchvision.datasets.MNIST(
    root="./data",
    train=True,
    download=True,
    transform=transform_augmented
)

test_dataset = torchvision.datasets.MNIST(
    root="./data",
    train=False,
    download=True,
    transform=transforms.ToTensor()
)

train_loader_aug = DataLoader(train_dataset_aug, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

len(train_dataset_aug), len(test_dataset)
# Out:
# (60000, 10000)

# %%
num_images = 6

plt.figure(figsize=(10, 3))

for i in range(num_images):
    image, label = train_dataset_aug[i]

    plt.subplot(1, num_images, i + 1)
    plt.imshow(image.squeeze(), cmap="gray")
    plt.title(f"Label: {label}")
    plt.axis("off")

plt.suptitle("Sample images from the MNIST training dataset")
plt.show()

# %% [markdown]
# Train the **same model** using the augmented training dataset.
#
# Compare:
# - Training loss
# - Test accuracy
#
# with the results obtained using original MNIST.

# %%
model_aug = MLP_MNIST().to(device)
model_aug
# Out:
# MLP_MNIST(
#   (net): Sequential(
#     (0): Flatten(start_dim=1, end_dim=-1)
#     (1): Linear(in_features=784, out_features=256, bias=True)
#     (2): ReLU()
#     (3): Linear(in_features=256, out_features=10, bias=True)
#   )
# )

# %%
criterion2 = nn.CrossEntropyLoss()
optimizer2 = optim.Adam(model_aug.parameters(), lr=1e-3)

# %%
## TODO

# train
epochs = 10

for epoch in range(epochs):
    model_aug.train()
    running_loss = 0.0

    for images, labels in train_loader_aug:
        images = images.to(device)
        labels = labels.to(device)

        optimizer2.zero_grad()
        outputs = model_aug(images)
        loss = criterion2(outputs, labels)

        loss.backward()
        optimizer2.step()

        running_loss += loss.item()

    avg_loss = running_loss / len(train_loader_aug)
    print(f"Epoch {epoch+1}/{epochs} - Loss: {avg_loss:.4f}")
# Out:
# Epoch 1/10 - Loss: 1.2352
# Epoch 2/10 - Loss: 0.7076
# Epoch 3/10 - Loss: 0.5837
# Epoch 4/10 - Loss: 0.5263
# Epoch 5/10 - Loss: 0.4819
# Epoch 6/10 - Loss: 0.4538
# Epoch 7/10 - Loss: 0.4286
# Epoch 8/10 - Loss: 0.4095
# Epoch 9/10 - Loss: 0.3922
# Epoch 10/10 - Loss: 0.3820

# %%
## TODO

# evaluate
model_aug.eval()
correct = 0
total = 0

with torch.no_grad():
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)

        outputs = model_aug(images)
        _, predicted = torch.max(outputs, 1)

        total += labels.size(0)
        correct += (predicted == labels).sum().item()

accuracy = correct / total
print(f"Test Accuracy: {accuracy:.4f}")
accuracy
# Out:
# Test Accuracy: 0.9340
# 0.934

# %% [markdown]
# ## 5) What do we observe? (Reflection)
#
#  - Why does the same fully-connected model perform worse on shifted and rotated MNIST images compared to vanilla MNIST?
#
# The fully-connected model performs worse on shifted and rotated MNIST images because it does not capture spatial relationships or local patterns in the image. When digits are moved or rotated, the pixel positions change, and the model cannot generalize well since it treats each pixel independently, making it sensitive to such transformations.
#
#  - What limitation of fully-connected networks does this experiment reveal when dealing with images?
#
# Fully-connected networks ignore the spatial structure of images and treat all pixels as independent features. This makes them unable to recognize patterns that are shifted, rotated, or located in different parts of the image, leading to poor generalization on transformed images.
#
#
# - Based on these results, what properties should a better model for image data have?
#
# A better model for image data should capture spatial hierarchies and local patterns, making use of convolutional layers that can learn translation-invariant features.
#
#  -> Additionally, it should be robust to variations in position and orientation, allowing for better generalization across different image transformations.

# %% [markdown]
# ## 6) Looking ahead — why CNNs?
#
# In the next assignment, we will replace this MLP with **Convolutional Neural Networks**.
#
# CNNs:
# - Exploit **spatial structure**
# - Share parameters
# - Achieve **much higher accuracy** on image tasks
#
# 👉 You should expect a **significant accuracy improvement** in the next assignment.
